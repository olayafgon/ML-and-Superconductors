# %%
import numpy as np
import pandas as pd
import os

# %%
directory = './Data_raw/Data_BCC'

df_total = pd.DataFrame()

files = os.listdir(directory)
for file in files:
    print('Check: ' + file)

    file_path = os.path.join(directory, file)

    name_split = file.split('_')
    df_conds = pd.DataFrame({'Prototype_Formula': [name_split[1]],
                             'ICSD': [name_split[-1].split('.')[0]],
                             'Bravais_Lattice': [name_split[0]]})
    
    print(df_conds.head())
    print('-----------------')
    

    df_simulation = pd.read_csv(file_path, skiprows = 5, nrows = 1, delim_whitespace=True,
                 names = ['Max_Energy',
                        'Min_Energy',
                        'Grid_Points',
                        'Fermi_Energy',
                        'no_info'
                        ])
    grid_points = int(df_simulation.iloc[0]['Grid_Points'])
    df_simulation['no_info'].drop()
    df_simconds = pd.concat([df_conds, df_simulation], axis=1)
    
    print(df_simconds.head())

    df_dos = pd.read_csv(file_path, skiprows = 6, nrows = grid_points, delim_whitespace=True,
                 names = ['Energy',
                        'State_Density',
                        'State_Density_Integrated'
                        ])
    
    # Replicar las filas de df_combined para que coincidan con la longitud de df_dos
    df_combined_replicated = pd.concat([df_combined]*len(df_dos), ignore_index=True)
    
    # Agregar los DataFrames al DataFrame total
    df_total = pd.concat([df_total, df_combined_replicated], ignore_index=True)
    df_total = pd.concat([df_total, df_dos], ignore_index=True)
# Out:
# Check: BCC_Bi4Ge3O12_ICSD_260560.txt
#   Prototype_Formula    ICSD Bravais_Lattice
# 0         Bi4Ge3O12  260560             BCC
# -----------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18180\730220047.py in ?()
#      24                         'Fermi_Energy',
#      25                         'no_info'
#      26                         ])
#      27     grid_points = int(df_simulation.iloc[0]['Grid_Points'])
# ---> 28     df_simulation['no_info'].drop()
#      29     df_simconds = pd.concat([df_conds, df_simulation], axis=1)
#      30
#      31     print(df_simconds.head())
#
# c:\Users\olaya\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5081         falcon  speed     320.0
#    5082                 length      0.3
#    5083         dtype: float64
# ...

# %%
df_total.head()
# Out:
#   Prototype_Formula ICSD Bravais_Lattice  Max_Energy  Min_Energy  Grid_Points  \
# 0               NaN  NaN             NaN        45.0       -30.0       5000.0
# 0               NaN  NaN             NaN         NaN         NaN          NaN
# 1               NaN  NaN             NaN         NaN         NaN          NaN
# 2               NaN  NaN             NaN         NaN         NaN          NaN
# 3               NaN  NaN             NaN         NaN         NaN          NaN
#
#    Fermi_Energy  no_info  Energy  State_Density  State_Density_Integrated
# 0      3.355421      1.0     NaN            NaN                       NaN
# 0           NaN      NaN -30.000            0.0                       0.0
# 1           NaN      NaN -29.985            0.0                       0.0
# 2           NaN      NaN -29.970            0.0                       0.0
# 3           NaN      NaN -29.955            0.0                       0.0
